# %%
import matplotlib.pyplot as plt

# %%
from skimage import io

# %%
photo = io.imread('panda.jpg')
type(photo)
# Out:
# imageio.core.util.Array

# %%
photo.shape
# Out:
# (800, 1200, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)
